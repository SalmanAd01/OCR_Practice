# %%
# import tesseract
from PIL import Image
import pytesseract
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %%
img = cv2.imread('ui100.png')

# %%
plt.imshow(img)
plt.show()

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Nia”
#
# SIES GRADUATE SCHOOL OF TECHNOLOGY
#
# POUND 1.0 RRUIORY HHA Hai med acorot
# Tes 2117 emwez er anee bay serv arse
# Theory Examination mark eheet
#
# GE Exam hold during First Halt of 2027
#
# Centra Name SIESGST. Neful Centre Code 690
#
# Granch:
# Sem with Bcheme- t
# Subject with subject code:
# a)
# mca
# | name oftnestudent f Sentra. | Ne |e) bo) ec; ale | t rian Deseret mene Teo)
# PT Soiman pase [ee Tota taleiststest , [as °
# x . aa 42ls|2}2/[2]4 [a5 |
# 422134032 a2 (s(slo [3] S|2 | 3¢ ° Zo o
# Rat J as 4[s S af A/a] 29
# " 424134033 az giz S13i2 bad °
# tuna) a Telalatelet et eed a a
# bp—+-—_Keumabaar 471134034 az SIS 4 {2156 4o i) °
# [ Ba. cote a |oislalsi2lul<s| ° i
# 421134035 az SI4[S1(2/S5/12/ 329
# Pica bata a [s[atststatst se ° }sat °
# Bo - 421234036 a2 G{l2}2 wid 3S 0 0
# Ras 1 as S|S/3/ Si 2/12] o2¢ ‘“
# 7 Dhiras_ 424134037 az sle(2zl[ule Dl 24 ° 24 oD
# ‘e. Qa S 312 a 2 2 28
# 7 Sroel) 421134038 a2 Ss 3% 34 fo
# Deniaing_ a ylotelelerebesq ° 34
# ...
